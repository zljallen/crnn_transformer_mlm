# %%
from utils import *
import os,torch,math
from DL_ClassifierModel import *
from matplotlib import pyplot as plt
from collections import Counter
import numpy as np
import cv2
# %matplotlib inline
# import seaborn as sns

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "0"  #选择需要使用的GPU
torch.cuda.device_count()
# Out:
# 0

# %%
# 直接读取实际数据
# dataClass = DataClass_Batch('../DataSet', 'Data/train.txt', 'Data/test.txt', 'Data/vocabulary_agnostic.txt', 'Data/vocabulary_semantic.txt', encoding='semantic', hs=128, dropBLANK=True)

dataClass = DataClass_Batch('../MiniData', 'Data/Mtrain.txt', 'Data/Mtest.txt', 'Data/vocabulary_agnostic.txt', 'Data/vocabulary_semantic.txt', encoding='semantic', hs=128, dropBLANK=True)

# %%
# 建立模型
model = Trans2trans(classNum=len(dataClass.label), seqMaxLen=dataClass.maxItems*4+1+dataClass.maxItems+1,
                    tknDropout=0.1, embDropout=0.0, hdnDropout=0.1, fcDropout=0.0,
                    imgHeight=128, contextSizeList=[1,5,25,49], feaSize=1024, rnnLayerNum=2,
                    transNum=4, dk=48, multiNum=8, usePos=True, usePreLN=True,
                    maxItems=dataClass.maxItems, device=torch.device('cuda'))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-75e1adb5ecf7> in <module>
#       4                     imgHeight=128, contextSizeList=[1,5,25,49], feaSize=1024, rnnLayerNum=2,
#       5                     transNum=4, dk=48, multiNum=8, usePos=True, usePreLN=True,
# ----> 6                     maxItems=dataClass.maxItems, device=torch.device('cuda'))
#
# ~\Desktop\Pro\Code\DL_ClassifierModel.py in __init__(self, classNum, seqMaxLen, imgHeight, contextSizeList, feaSize, maxItems, rnnLayerNum, transNum, dk, multiNum, usePos, usePreLN, embDropout, tknDropout, hdnDropout, fcDropout, device)
#     256
#     257         self.maxItems = maxItems
# --> 258         self.seqCNN = TextCNN(imgHeight, feaSize//len(contextSizeList), contextSizeList, reduction='none', actFunc=nn.ReLU, bn=True).to(device)
#     259
#     260         self.eSeqRNN = TextLSTM(feaSize, feaSize//2, num_layers=rnnLayerNum, dropout=hdnDropout, bidirectional=True, name='encoder').to(device)
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in to(self, *args, **kwargs)
#     605             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     606
# --> 607         return self._apply(convert)
#     608
#     609     def register_backward_hook(
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     352     def _apply(self, fn):
#     353         for module in self.children():
# --> 354             module._apply(fn)
#     355
#     356         def compute_should_use_set_data(tensor, tensor_applied):
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     352     def _apply(self, fn):
#     353         for module in self.children():
# --> 354             module._apply(fn)
#     355
#     356         def compute_should_use_set_data(tensor, tensor_applied):
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _apply(self, fn)
#     374                 # `with torch.no_grad():`
#     375                 with torch.no_grad():
# --> 376                     param_applied = fn(param)
#     377                 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     378                 if should_use_set_data:
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in convert(t)
#     603             if convert_to_format is not None and t.dim() == 4:
#     604                 return t.to(device, dtype if t.is_floating_point() else None, non_blocking, memory_format=convert_to_format)
# --> 605             return t.to(device, dtype if t.is_floating_point() else None, non_blocking)
#     606
#     607         return self._apply(convert)
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     184             raise RuntimeError(
#     185                 "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 186         _check_driver()
#     187         if _cudart is None:
#     188             raise AssertionError(
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      59 def _check_driver():
#      60     if not hasattr(torch._C, '_cuda_isDriverSufficient'):
# ---> 61         raise AssertionError("Torch not compiled with CUDA enabled")
#      62     if not torch._C._cuda_isDriverSufficient():
#      63         if torch._C._cuda_getDriverVersion() == 0:
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
#模型训练并保存最好的模型
model.train(dataClass, trainSize=16, batchSize=16, validSize=64, epoch=128, stopRounds=-1, earlyStop=20, saveRounds=1, 
            optimType='Adam', lr=0.0001, weightDecay=0, warmupEpochs=0, isHigherBetter=False, metrics="editDistDivSeq", report=["seqErrorDivSeq", "editDistDivSeq", "editDistDivSymbol"], 
            savePath='TrainModel_xxx', metrics_savefile="tmp.npz")
# Out:
# Epoch 1 with learning rate 0.000100...
#   2%|█▏                                                                 | 1/57 [01:42<1:35:57, 102.81s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-79c4f787bc42> in <module>
#       2 model.train(dataClass, trainSize=16, batchSize=16, validSize=64, epoch=128, stopRounds=-1, earlyStop=20, saveRounds=1,
#       3             optimType='Adam', lr=0.0001, weightDecay=0, warmupEpochs=0, isHigherBetter=False, metrics="editDistDivSeq", report=["seqErrorDivSeq", "editDistDivSeq", "editDistDivSymbol"],
# ----> 4             savePath='TrainModel_xxx', metrics_savefile="tmp.npz")
#
# ~\Desktop\Pro\Code\DL_ClassifierModel.py in train(self, dataClass, trainSize, batchSize, validSize, epoch, stopRounds, earlyStop, saveRounds, optimType, warmupEpochs, lr, momentum, weightDecay, isHigherBetter, metrics, report, savePath, metrics_savefile)
#     162                 self.to_train_mode()
#     163                 X,Y = next(trainStream)
# --> 164                 loss = self._train_step(X,Y, optimizer) #得到交叉熵损失
#     165                 schedulerRLR.step()
#     166 #                 pbar.set_description(f"Training Loss: {loss}; Learning rate: {optimizer.state_dict()['param_groups'][0]['lr']:.6f}")
#
# ~\Desktop\Pro\Code\DL_ClassifierModel.py in _train_step(self, X, Y, optimizer)
#      65             self.stepCounter = 0
#      66             p = True
# ---> 67         loss = self.calculate_loss(X, Y)/self.stepUpdate
#      68         # print(loss)
#      69         loss.backward()
#
# ~\Desktop\Pro\Code\DL_ClassifierModel.py in calculate_loss(self, X, Y)
#      53         # print(X['imgArr'].shape, X['imgLab'].shape, X['inputLen'], X['targetLen'])
#      54         # print(Y.shape)
# ---> 55         out = self.calculate_y_logit(X) #得到预测输出out ( batchSize*(maxItems+1)*len(dataClass.id2lab2) )
#      56         Y = Y.reshape(-1) #得到实际标签Y
#      57         Y_logit = out['y_logit'].reshape(len(Y),-1)
#
# ~\Desktop\Pro\Code\DL_ClassifierModel.py in calculate_y_logit(self, X)
#     311             x,_ = nn.parallel.data_parallel(self.transformer,x)
#     312         else:
# --> 313             x,_ = self.transformer(x) # => batchSize × (seqLen+1+maxItems*4+1) × feaSize
#     314
#     315         y = x[:,-self.maxItems-2:-1]
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\Desktop\Pro\Code\nnLayer.py in forward(self, x, xlen)
#     155             x = x+self.posEmb
#     156         x = self.dropout(x) # => batchSize × seqLen × feaSize
# --> 157         x, _ = self.transformerLayers((x, xlen)) # => batchSize × seqLen × feaSize
#     158         return x, _
#     159
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\Desktop\Pro\Code\nnLayer.py in forward(self, input)
#     135         # x: batchSize × seqLen × feaSize; xlen: batchSize
#     136         z = self.selfAttn(x, xlen) # => batchSize × seqLen × feaSize
# --> 137         return (self.ffn(x, z),xlen) # => batchSize × seqLen × feaSize
#     138
#     139 class TextPreLNTransformer_seq2seq(nn.Module):
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~\Desktop\Pro\Code\nnLayer.py in forward(self, x, z)
#     122     def forward(self, x, z):
#     123         z = x + self.dropout(z) # => batchSize × seqLen × feaSize
# --> 124         ffnx = self.Wffn(self.layerNorm2(z)) # => batchSize × seqLen × feaSize
#     125         return z+self.dropout(ffnx) # => batchSize × seqLen × feaSize
#     126
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# D:\CodeProgramming\anoconda\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
# -> 1676         output = input.matmul(weight.t())
#    1677         if bias is not None:
#    1678             output += bias
#
# KeyboardInterrupt:
